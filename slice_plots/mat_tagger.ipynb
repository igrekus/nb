# %%
import pandas as pd
from numpy import nan

# %%
mats = {
    '2021-07-28_slice_glue': {
        81: {'mat': 'Необонд классик', 'glue': 'без клея'},
        82: {'mat': 'Необонд классик', 'glue': 'без клея'},
        83: {'mat': 'Необонд классик', 'glue': 'без клея'},
        84: {'mat': 'Гознак 200г', 'glue': 'Суспензия акриловых латексов'},
        85: {'mat': 'Гознак 200г', 'glue': 'Суспензия акриловых латексов'},
        86: {'mat': 'Гознак 200г', 'glue': 'Суспензия акриловых латексов'},
        87: {'mat': 'Гознак 200г', 'glue': 'Клей Nollax S35.3032'},
        88: {'mat': 'Гознак 200г', 'glue': 'Клей Nollax S35.3032'},
        89: {'mat': 'Гознак 200г', 'glue': 'Клей Nollax S35.3032'},
        90: {'mat': 'Гознак 200г', 'glue': 'Клей OpSec WRS853'},
        91: {'mat': 'Гознак 200г', 'glue': 'Клей OpSec WRS853'},
        92: {'mat': 'Гознак 200г', 'glue': 'Клей OpSec WRS853'},
        93: {'mat': 'Гознак 200г', 'glue': 'Клей Centro Grafico 125WB'},
        94: {'mat': 'Гознак 200г', 'glue': 'Клей Centro Grafico 125WB'},
        95: {'mat': 'Гознак 200г', 'glue': 'Клей Centro Grafico 125WB'},
        96: {'mat': 'Pretex 200г', 'glue': 'Суспензия акриловых латексов'},
        97: {'mat': 'Pretex 200г', 'glue': 'Суспензия акриловых латексов'},
        98: {'mat': 'Pretex 200г', 'glue': 'Суспензия акриловых латексов'},
        99: {'mat': 'Pretex 200г', 'glue': 'Клей Nollax S35.3032'},
        100: {'mat': 'Pretex 200г', 'glue': 'Клей Nollax S35.3032'},
        101: {'mat': 'Pretex 200г', 'glue': 'Клей Nollax S35.3032'},
        102: {'mat': 'Pretex 200г', 'glue': 'Клей OpSec WRS853'},
        103: {'mat': 'Pretex 200г', 'glue': 'Клей OpSec WRS853'},
        104: {'mat': 'Pretex 200г', 'glue': 'Клей OpSec WRS853'},
        105: {'mat': 'Pretex 200г', 'glue': 'Клей Centro Grafico 125WB'},
        106: {'mat': 'Pretex 200г', 'glue': 'Клей Centro Grafico 125WB'},
        107: {'mat': 'Pretex 200г', 'glue': 'Клей Centro Grafico 125WB'},
        108: {'mat': 'Pretex 150г', 'glue': 'Суспензия акриловых латексов'},
        109: {'mat': 'Pretex 150г', 'glue': 'Суспензия акриловых латексов'},
        110: {'mat': 'Pretex 150г', 'glue': 'Суспензия акриловых латексов'},
        111: {'mat': 'Pretex 150г', 'glue': 'Клей Nollax S35.3032'},
        112: {'mat': 'Pretex 150г', 'glue': 'Клей Nollax S35.3032'},
        113: {'mat': 'Pretex 150г', 'glue': 'Клей Nollax S35.3032'},
        114: {'mat': 'Pretex 150г', 'glue': 'Клей OpSec WRS853'},
        115: {'mat': 'Pretex 150г', 'glue': 'Клей OpSec WRS853'},
        116: {'mat': 'Pretex 150г', 'glue': 'Клей OpSec WRS853'},
        117: {'mat': 'Pretex 150г', 'glue': 'Клей Centro Grafico 125WB'},
        118: {'mat': 'Pretex 150г', 'glue': 'Клей Centro Grafico 125WB'},
        119: {'mat': 'Pretex 150г', 'glue': 'Клей Centro Grafico 125WB'},
        120: {'mat': 'Omega Silk 150г', 'glue': 'Суспензия акриловых латексов'},
        121: {'mat': 'Omega Silk 150г', 'glue': 'Суспензия акриловых латексов'},
        122: {'mat': 'Omega Silk 150г', 'glue': 'Суспензия акриловых латексов'},
        123: {'mat': 'Omega Silk 150г', 'glue': 'Клей Nollax S35.3032'},
        124: {'mat': 'Omega Silk 150г', 'glue': 'Клей Nollax S35.3032'},
        125: {'mat': 'Omega Silk 150г', 'glue': 'Клей Nollax S35.3032'},
        126: {'mat': 'Omega Silk 150г', 'glue': 'Клей OpSec WRS853'},
        127: {'mat': 'Omega Silk 150г', 'glue': 'Клей OpSec WRS853'},
        128: {'mat': 'Omega Silk 150г', 'glue': 'Клей OpSec WRS853'},
        129: {'mat': 'Omega Silk 150г', 'glue': 'Клей Centro Grafico 125WB'},
        130: {'mat': 'Omega Silk 150г', 'glue': 'Клей Centro Grafico 125WB'},
        131: {'mat': 'Omega Silk 150г', 'glue': 'Клей Centro Grafico 125WB'},
        132: {'mat': 'Neobond 200г', 'glue': 'Суспензия акриловых латексов'},
        133: {'mat': 'Neobond 200г', 'glue': 'Суспензия акриловых латексов'},
        134: {'mat': 'Neobond 200г', 'glue': 'Суспензия акриловых латексов'},
        135: {'mat': 'Neobond 200г', 'glue': 'Клей Nollax S35.3032'},
        136: {'mat': 'Neobond 200г', 'glue': 'Клей Nollax S35.3032'},
        137: {'mat': 'Neobond 200г', 'glue': 'Клей Nollax S35.3032'},
        138: {'mat': 'Neobond 200г', 'glue': 'Клей OpSec WRS853'},
        139: {'mat': 'Neobond 200г', 'glue': 'Клей OpSec WRS853'},
        140: {'mat': 'Neobond 200г', 'glue': 'Клей OpSec WRS853'},
        141: {'mat': 'Neobond 200г', 'glue': 'Клей Centro Grafico 125WB'},
        142: {'mat': 'Neobond 200г', 'glue': 'Клей Centro Grafico 125WB'},
        143: {'mat': 'Neobond 200г', 'glue': 'Клей Centro Grafico 125WB'},
    },
    '2021-08-02_slice_rate': {
        144: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Клей', 'rate': 0},
        145: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Клей', 'rate': 0},
        146: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Клей', 'rate': 0},
        147: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Бумага', 'rate': 0},
        148: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Бумага', 'rate': 0},
        149: {'mat': 'Необонд классик', 'glue_paper': 'Клей-Бумага', 'rate': 0},
        150: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        151: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        152: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        153: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        154: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        155: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        156: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        158: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        159: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        160: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        161: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        162: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        163: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        164: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        165: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        166: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        167: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        168: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        169: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        170: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        171: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 11800},
        172: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        173: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        174: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 11800},
        175: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 111200},
        176: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 111200},
        177: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'rate': 111200},
        178: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 111200},
        179: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 111200},
        180: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'rate': 111200},
        181: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        182: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        183: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        184: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        185: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        186: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        187: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        188: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        189: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        190: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        191: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        192: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        193: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        194: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        195: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        196: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        197: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        198: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 21800},
        199: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        200: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        201: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 21800},
        202: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 211200},
        203: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 211200},
        204: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'rate': 211200},
        205: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 211200},
        206: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 211200},
        207: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'rate': 211200},
        208: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        209: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        210: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        211: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        212: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        213: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        214: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        215: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        216: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        217: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        218: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        219: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        220: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        221: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        222: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        224: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        225: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        226: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        228: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        229: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 31800},
        230: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        231: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        232: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 31800},
        233: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 311200},
        234: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 311200},
        235: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'rate': 311200},
        236: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 311200},
        237: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 311200},
        238: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'rate': 311200},
        239: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        240: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        241: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        242: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        243: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        244: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        245: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        246: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        247: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        248: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        249: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        250: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        251: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        252: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        253: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 41800},
        254: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        255: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        256: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 41800},
        257: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 411200},
        258: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 411200},
        259: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'rate': 411200},
        260: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 411200},
        261: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 411200},
        262: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'rate': 411200},
        263: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        264: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        265: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        266: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        267: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        268: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        269: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        270: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        271: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        272: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        273: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        274: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        275: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        276: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        277: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        278: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        279: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        280: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        281: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        282: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        283: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 51800},
        284: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        285: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        286: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 51800},
        287: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 511200},
        288: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 511200},
        289: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'rate': 511200},
        290: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 511200},
        291: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 511200},
        292: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'rate': 511200},
    },
    '2021-09-06_slice_silk': {
        433: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        434: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        435: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        436: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        437: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        438: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        439: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        440: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        441: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        442: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        443: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        444: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        445: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        446: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        447: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        448: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        449: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        450: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        451: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        452: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        453: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        454: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        455: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        456: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        457: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        458: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        459: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        460: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        461: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        462: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        463: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        464: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        465: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        466: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        467: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        468: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        469: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        470: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        471: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        472: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        473: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        474: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        475: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        476: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        477: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        478: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        479: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        480: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        481: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        482: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        483: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 70},
        484: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        485: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        486: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 70},
        487: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        488: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        489: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 70},
        490: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        491: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        492: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 70},
        493: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        494: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        495: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        496: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        497: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        498: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        499: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        500: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        501: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        502: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        503: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        504: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        505: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        506: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        507: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        508: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        509: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        510: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        511: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        512: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        514: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        515: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        516: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        517: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        518: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        519: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        520: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        521: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        522: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        523: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        524: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        525: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        526: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        527: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        528: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        529: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        530: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        531: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        532: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        533: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        534: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        535: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        536: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        537: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        538: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        539: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        540: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        541: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        542: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        544: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        545: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 90},
        546: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        547: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        548: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 90},
        549: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        550: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        551: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 90},
        552: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        553: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        554: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 90},
        555: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        556: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        557: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        558: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        559: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        560: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        561: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        562: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        563: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        564: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        565: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        566: {'mat': 'Гознак 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        567: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        568: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        569: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        570: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        571: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        572: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        573: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        574: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        575: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        576: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        577: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        578: {'mat': 'Pretex 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        579: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        580: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        581: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        582: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        583: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        584: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        585: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        586: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        587: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        588: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        589: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        590: {'mat': 'Pretex 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        591: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        592: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        593: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        594: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        595: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        596: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        597: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        598: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        599: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        600: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        601: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        602: {'mat': 'Omega Silk 150г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        603: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        604: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        605: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Сетка', 'cell_size': 100},
        606: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        607: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        608: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Сетка', 'cell_size': 100},
        609: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        610: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        611: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Бумага', 'pattern': 'Растр', 'cell_size': 100},
        612: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        613: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
        614: {'mat': 'Neobond 200г', 'glue_paper': 'Клей-Клей', 'pattern': 'Растр', 'cell_size': 100},
    },
    '2021-09-20_slice_roller': {
        840: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 70},
        841: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 70},
        842: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        843: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        844: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        845: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        846: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        847: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        848: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        849: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        850: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        851: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        852: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        853: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        854: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        855: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        856: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        857: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        858: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        859: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        860: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        861: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        862: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        863: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        864: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        865: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 70},
        866: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        867: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        868: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 70},
        869: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 70},
        870: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 70},
        871: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 70},
        872: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 70},
        873: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 70},
        874: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 70},
        875: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 70},
        876: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 70},
        877: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 70},
        878: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        879: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        880: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 70},
        881: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        882: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        883: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 70},
        884: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        885: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        886: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 70},
        887: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 70},
        888: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 70},
        889: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 70},
        890: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 70},
        891: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 70},
        892: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 70},
        893: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 70},
        894: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 70},
        895: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 70},
        896: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        897: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        898: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        899: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        900: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        901: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        902: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        903: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        904: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        905: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        906: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        907: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        908: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        909: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        910: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        911: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        912: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        913: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        914: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        915: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        916: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        917: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        918: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        919: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        920: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        921: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        922: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        923: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        924: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        925: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        926: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 90},
        927: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 90},
        928: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 90},
        929: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 90},
        930: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 90},
        931: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 90},
        932: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        933: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        934: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        935: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        936: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        937: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        938: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        939: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        940: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 90},
        941: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        942: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        943: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 90},
        944: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        945: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        946: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        947: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        948: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        949: {'mat': 'Гознак 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        950: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        951: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        952: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        953: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        954: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        955: {'mat': 'Omega Silk 150г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        956: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        957: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        958: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        959: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        960: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        961: {'mat': 'Neobond 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        962: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        963: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        964: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        965: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        966: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        967: {'mat': 'Гознак 200г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        968: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        969: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        970: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 100},
        971: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        972: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        973: {'mat': 'Pretex 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 100},
        974: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 100},
        975: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 100},
        976: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Сетка', 'cell_size': 100},
        977: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 100},
        978: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 100},
        979: {'mat': 'Гознак 200г', 'strip': 'Pretex 200г', 'pattern': 'Растр', 'cell_size': 100},
        980: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        981: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        982: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 100},
        983: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        984: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        985: {'mat': 'Neobond 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 100},
        986: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        987: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        988: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Сетка', 'cell_size': 100},
        989: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        990: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        991: {'mat': 'Omega Silk 150г', 'strip': 'Neobond 200г', 'pattern': 'Растр', 'cell_size': 100},
        992: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 100},
        993: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 100},
        994: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/3', 'cell_size': 100},
        995: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 100},
        996: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 100},
        997: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/4', 'cell_size': 100},
        998: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 100},
        999: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 100},
        1000: {'mat': 'Гознак 200г', 'strip': 'Гознак 80г', 'pattern': 'Клей-Клей 1/5', 'cell_size': 100},
        1001: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        1002: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        1003: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Сетка', 'cell_size': 90},
        1004: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        1005: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        1006: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Omega Silk 150г', 'pattern': 'Растр', 'cell_size': 90},
        1007: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1008: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1009: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1010: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
        1011: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
        1012: {'mat': 'Omega Silk 150г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
        1013: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1014: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1015: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1016: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        1017: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        1018: {'mat': 'Neobond клеевая суспензия HS 26 200г', 'strip': 'Гознак 200г', 'pattern': 'Растр', 'cell_size': 90},
        1019: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1020: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1021: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Сетка', 'cell_size': 90},
        1022: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
        1023: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
        1024: {'mat': 'Гознак 200г', 'strip': 'Neobond клеевая суспензия HS 26 200г', 'pattern': 'Растр', 'cell_size': 90},
    },
}
ms = []
for d in mats.values():
    for k, dt in d.items():
        values = {'measure': k, **dt}
        ms.append(values)

df_mats = pd.DataFrame(ms)
df_mats.replace([nan], '', inplace=True)
df_mats.head()
# Out:
#    measure              mat                          glue glue_paper rate  \
# 0       81  Необонд классик                      без клея
# 1       82  Необонд классик                      без клея
# 2       83  Необонд классик                      без клея
# 3       84      Гознак 200г  Суспензия акриловых латексов
# 4       85      Гознак 200г  Суспензия акриловых латексов
#
#   pattern cell_size strip
# 0
# 1
# 2
# 3
# 4

# %%
df = pd.read_excel(r'.\data\master.xlsx', engine='openpyxl')
df_f = pd.read_excel(r'.\data\master_filtered.xlsx', engine='openpyxl')

# %%
df_merged = pd.merge(df, df_mats, how='left', on='measure')
df_f_merged = pd.merge(df_f, df_mats, how='left', on='measure')
df_f_merged.head()
# Out:
#    L(mm)  F(N)  deriv                  batch  measure              mat  \
# 0   0.00   0.0    NaN  2021-07-28_slice_glue       81  Необонд классик
# 1   0.08   0.1   1.25  2021-07-28_slice_glue       81  Необонд классик
# 2   0.13   0.0  -2.00  2021-07-28_slice_glue       81  Необонд классик
# 3   0.18   0.1   2.00  2021-07-28_slice_glue       81  Необонд классик
# 4   0.23   0.0  -2.00  2021-07-28_slice_glue       81  Необонд классик
#
#        glue glue_paper rate pattern cell_size strip
# 0  без клея
# 1  без клея
# 2  без клея
# 3  без клея
# 4  без клея

# %%
df_merged.to_excel('master_full.xlsx', engine='openpyxl')
df_f_merged.to_excel('master_filtered_full.xlsx', engine='openpyxl')
